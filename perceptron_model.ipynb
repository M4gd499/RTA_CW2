# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, random_state=42)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.title('Train')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Perceptron()
model.fit(X_train, y_train)
# Out:
# Perceptron()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Dokładność modelu: {accuracy:.2f}')
print(classification_report(y_test, y_pred))
# Out:
# Dokładność modelu: 0.80
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83       148
#            1       0.97      0.63      0.76       152
#
#     accuracy                           0.80       300
#    macro avg       0.85      0.81      0.80       300
# weighted avg       0.85      0.80      0.80       300

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.title('Granica decyzyjna perceptronu')
plt.show()

# %%
with open('perceptron.pickle', 'wb') as f:
    pickle.dump(per_clf, f)
with open('perceptron.pickle', 'rb') as f:
    nn = pickle.load(f)
nn_prediction = nn.predict([[1.9, 0.6]])
print("Prediction for [1.9, 0.6]:", nn_prediction)
